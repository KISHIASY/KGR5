# %%
import pandas as pd
import numpy as np

# %%
edo = pd.read_csv(r'C:\KGR5\edogawa_kurokawa.csv', encoding = 'cp932')

# %%
edo[0:10]
# Out:
#       地区  クラスタ  自転車盗数  区立自転車駐車場設置状況  自転車駐輪場一覧(NAVITIME)  使用料制駐輪場  \
# 0   東小松川     0     32             0                   0        0
# 1  西小松川町     0      3             0                   0        0
# 2    小松川     0     40             0                   1        0
# 3    西葛西     1    172             5                   4        0
# 4    中葛西     1    137             3                   1        0
# 5    北葛西     0     42             0                   0        0
# 6    南葛西     1    113             0                   0        0
# 7    東葛西     1    170             0                   3        0
# 8     新堀     0      9             0                   0        0
# 9    清新町     0     43             0                   0        0
#
#    駐輪場(Google map)  公園(Google map)
# 0                0               4
# 1                0               3
# 2                1               9
# 3                4               9
# 4                1               4
# ...

# %%
edo_tmp = edo.drop(['地区', 'クラスタ'], axis=1)
#edo_tmp = edo_tmp.drop('Unnamed: 8', axis=1)
edo_tmp[0:10]
# Out:
#    自転車盗数  区立自転車駐車場設置状況  自転車駐輪場一覧(NAVITIME)  使用料制駐輪場  駐輪場(Google map)  \
# 0     32             0                   0        0                0
# 1      3             0                   0        0                0
# 2     40             0                   1        0                1
# 3    172             5                   4        0                4
# 4    137             3                   1        0                1
# 5     42             0                   0        0                0
# 6    113             0                   0        0                1
# 7    170             0                   3        0                2
# 8      9             0                   0        0                0
# 9     43             0                   0        0                0
#
#    公園(Google map)
# 0               4
# 1               3
# 2               9
# 3               9
# 4               4
# 5               9
# 6              14
# 7               5
# 8               5
# ...

# %%
np_edo = edo_tmp.values

# %%
np_edo[0:10]
# Out:
# array([[ 32,   0,   0,   0,   0,   4],
#        [  3,   0,   0,   0,   0,   3],
#        [ 40,   0,   1,   0,   1,   9],
#        [172,   5,   4,   0,   4,   9],
#        [137,   3,   1,   0,   1,   4],
#        [ 42,   0,   0,   0,   0,   9],
#        [113,   0,   0,   0,   1,  14],
#        [170,   0,   3,   0,   2,   5],
#        [  9,   0,   0,   0,   0,   5],
#        [ 43,   0,   0,   0,   0,   7]], dtype=int64)

# %%
np.corrcoef([np_edo[:, 0], np_edo[:, 1], np_edo[:, 2], np_edo[:, 3], np_edo[:, 4], np_edo[:, 5]])
# Out:
# C:\Users\kishi\Anaconda3\envs\edogawa\lib\site-packages\numpy\lib\function_base.py:2400: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\kishi\Anaconda3\envs\edogawa\lib\site-packages\numpy\lib\function_base.py:2401: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# array([[1.        , 0.6514892 , 0.69438037,        nan, 0.69034572,
#         0.45945259],
#        [0.6514892 , 1.        , 0.69951132,        nan, 0.78562136,
#         0.30136845],
#        [0.69438037, 0.69951132, 1.        ,        nan, 0.91611286,
#         0.15336051],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan],
#        [0.69034572, 0.78562136, 0.91611286,        nan, 1.        ,
#         0.16637117],
#        [0.45945259, 0.30136845, 0.15336051,        nan, 0.16637117,
#         1.        ]])
